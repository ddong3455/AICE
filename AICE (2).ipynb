# %%
import pandas as pd

# %%
df=pd.read_csv("Clean_Dataset.csv")

# %%
df.drop([df.columns[0]], axis=1, inplace=True)

# %%
import random

# %%
import numpy as np

# %%
random.seed(2023)
np.random.seed(2023)

# %%
import numpy as np
import random

# 데이터프레임 크기 확인
num_rows, num_cols = df.shape

# df를 df_na로 복사
df_na = df.copy()

# 5000번 반복하여 NaN 값으로 변경
for _ in range(5000):
    row_index = random.randint(0, num_rows - 1)  # 행 인덱스 선택
    col_index = random.randint(0, num_cols - 1)  # 열 인덱스 선택
    df_na.iloc[row_index, col_index] = np.nan

# 결과 확인
print(df_na.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           299698 non-null  object
#  1   flight            299693 non-null  object
#  2   source_city       299686 non-null  object
#  3   departure_time    299709 non-null  object
#  4   stops             299709 non-null  object
#  5   arrival_time      299722 non-null  object
#  6   destination_city  299670 non-null  object
#  7   class             299694 non-null  object
#  8   duration          299671 non-null  float64
#  9   days_left         299712 non-null  float64
#  10  price             299721 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 25.2+ MB
# None

# %%
df_na.iloc[1]=np.nan
df_na.iloc[3]=np.nan

# %%
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           299698 non-null  object
#  1   flight            299693 non-null  object
#  2   source_city       299686 non-null  object
#  3   departure_time    299709 non-null  object
#  4   stops             299709 non-null  object
#  5   arrival_time      299722 non-null  object
#  6   destination_city  299670 non-null  object
#  7   class             299694 non-null  object
#  8   duration          299671 non-null  float64
#  9   days_left         299712 non-null  float64
#  10  price             299721 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 25.2+ MB

# %%
df_na.isnull().sum(axis=0)
# Out:
# airline             455
# flight              460
# source_city         467
# departure_time      444
# stops               444
# arrival_time        431
# destination_city    483
# class               459
# duration            482
# days_left           441
# price               432
# dtype: int64

# %%
df_na_origin=df_na.copy()

# %%
df_na=df_na.dropna()
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295201 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           295201 non-null  object
#  1   flight            295201 non-null  object
#  2   source_city       295201 non-null  object
#  3   departure_time    295201 non-null  object
#  4   stops             295201 non-null  object
#  5   arrival_time      295201 non-null  object
#  6   destination_city  295201 non-null  object
#  7   class             295201 non-null  object
#  8   duration          295201 non-null  float64
#  9   days_left         295201 non-null  float64
#  10  price             295201 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 27.0+ MB

# %%
df_na=df_na_origin.copy()
df_na=df_na.dropna(how='all')
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           299698 non-null  object
#  1   flight            299693 non-null  object
#  2   source_city       299686 non-null  object
#  3   departure_time    299709 non-null  object
#  4   stops             299709 non-null  object
#  5   arrival_time      299722 non-null  object
#  6   destination_city  299670 non-null  object
#  7   class             299694 non-null  object
#  8   duration          299671 non-null  float64
#  9   days_left         299712 non-null  float64
#  10  price             299721 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 25.2+ MB

# %%
df_na.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left   price
# 0           Mumbai  Economy      2.17        1.0  5953.0
# 1           Mumbai  Economy      2.33        1.0  5953.0
# 2           Mumbai  Economy      2.17        1.0  5956.0
# 3           Mumbai  Economy      2.25        1.0  5955.0
# 4           Mumbai  Economy      2.33        1.0  5955.0

# %%
df_na=df_na_origin.copy()
df_na=df_na.drop(['stops','flight'],axis=1)
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           299698 non-null  object
#  1   source_city       299686 non-null  object
#  2   departure_time    299709 non-null  object
#  3   arrival_time      299722 non-null  object
#  4   destination_city  299670 non-null  object
#  5   class             299694 non-null  object
#  6   duration          299671 non-null  float64
#  7   days_left         299712 non-null  float64
#  8   price             299721 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 20.6+ MB

# %%
df_na=df_na.dropna()
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 296088 entries, 0 to 300152
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           296088 non-null  object
#  1   source_city       296088 non-null  object
#  2   departure_time    296088 non-null  object
#  3   arrival_time      296088 non-null  object
#  4   destination_city  296088 non-null  object
#  5   class             296088 non-null  object
#  6   duration          296088 non-null  float64
#  7   days_left         296088 non-null  float64
#  8   price             296088 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 22.6+ MB

# %%
# 숫자 열만 선택
numeric_columns = df_na_origin.select_dtypes(include='number')

# 숫자 열의 누락된 값을 평균값으로 채움
numeric_columns_filled = numeric_columns.fillna(numeric_columns.mean())

# 채워진 숫자 열과 비숫자 열을 결합
df_na = pd.concat([numeric_columns_filled, df_na_origin.select_dtypes(exclude='number')], axis=1)

# 결과 DataFrame의 정보 확인
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   duration          300153 non-null  float64
#  1   days_left         300153 non-null  float64
#  2   price             300153 non-null  float64
#  3   airline           299698 non-null  object
#  4   flight            299693 non-null  object
#  5   source_city       299686 non-null  object
#  6   departure_time    299709 non-null  object
#  7   stops             299709 non-null  object
#  8   arrival_time      299722 non-null  object
#  9   destination_city  299670 non-null  object
#  10  class             299694 non-null  object
# dtypes: float64(3), object(8)
# memory usage: 25.2+ MB

# %%
df_na.head()
# Out:
#    duration  days_left   price   airline   flight source_city departure_time  \
# 0      2.17        1.0  5953.0  SpiceJet  SG-8709       Delhi        Evening
# 1      2.33        1.0  5953.0  SpiceJet  SG-8157       Delhi  Early_Morning
# 2      2.17        1.0  5956.0   AirAsia   I5-764       Delhi  Early_Morning
# 3      2.25        1.0  5955.0   Vistara   UK-995       Delhi        Morning
# 4      2.33        1.0  5955.0   Vistara   UK-963       Delhi        Morning
#
#   stops   arrival_time destination_city    class
# 0  zero          Night           Mumbai  Economy
# 1  zero        Morning           Mumbai  Economy
# 2  zero  Early_Morning           Mumbai  Economy
# 3  zero      Afternoon           Mumbai  Economy
# 4  zero        Morning           Mumbai  Economy

# %%
df_na=df_na.fillna(method='bfill')
df_na.info()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10672\2713743661.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_na=df_na.fillna(method='bfill')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   duration          300153 non-null  float64
#  1   days_left         300153 non-null  float64
#  2   price             300153 non-null  float64
#  3   airline           300153 non-null  object
#  4   flight            300153 non-null  object
#  5   source_city       300153 non-null  object
#  6   departure_time    300153 non-null  object
#  7   stops             300153 non-null  object
#  8   arrival_time      300153 non-null  object
#  9   destination_city  300153 non-null  object
#  10  class             300153 non-null  object
# dtypes: float64(3), object(8)
# memory usage: 25.2+ MB

# %%
df_na.head()
# Out:
#    duration  days_left   price   airline   flight source_city departure_time  \
# 0      2.17        1.0  5953.0  SpiceJet  SG-8709       Delhi        Evening
# 1      2.33        1.0  5953.0  SpiceJet  SG-8157       Delhi  Early_Morning
# 2      2.17        1.0  5956.0   AirAsia   I5-764       Delhi  Early_Morning
# 3      2.25        1.0  5955.0   Vistara   UK-995       Delhi        Morning
# 4      2.33        1.0  5955.0   Vistara   UK-963       Delhi        Morning
#
#   stops   arrival_time destination_city    class
# 0  zero          Night           Mumbai  Economy
# 1  zero        Morning           Mumbai  Economy
# 2  zero  Early_Morning           Mumbai  Economy
# 3  zero      Afternoon           Mumbai  Economy
# 4  zero        Morning           Mumbai  Economy

# %%
df[(abs((df['price']-df['price'].mean())/df['price'].std()))>1.96]
# Out:
#         airline  flight source_city departure_time stops arrival_time  \
# 206691  Vistara  UK-809       Delhi        Evening   one      Morning
# 206692  Vistara  UK-813       Delhi        Evening   one      Morning
# 206693  Vistara  UK-809       Delhi        Evening   one        Night
# 206694  Vistara  UK-809       Delhi        Evening   one        Night
# 206695  Vistara  UK-813       Delhi        Evening   one        Night
# ...         ...     ...         ...            ...   ...          ...
# 300148  Vistara  UK-822     Chennai        Morning   one      Evening
# 300149  Vistara  UK-826     Chennai      Afternoon   one        Night
# 300150  Vistara  UK-832     Chennai  Early_Morning   one        Night
# 300151  Vistara  UK-828     Chennai  Early_Morning   one      Evening
# 300152  Vistara  UK-822     Chennai        Morning   one      Evening
#
#        destination_city     class  duration  days_left  price
# 206691           Mumbai  Business     12.42          1  74640
# 206692           Mumbai  Business     14.67          1  74640
# 206693           Mumbai  Business     24.42          1  74640
# 206694           Mumbai  Business     26.00          1  74640
# 206695           Mumbai  Business     26.67          1  74640
# ...                 ...       ...       ...        ...    ...
# 300148        Hyderabad  Business     10.08         49  69265
# 300149        Hyderabad  Business     10.42         49  77105
# 300150        Hyderabad  Business     13.83         49  79099
# 300151        Hyderabad  Business     10.00         49  81585
# 300152        Hyderabad  Business     10.08         49  81585
#
# [12493 rows x 11 columns]

# %%
def findOutliers(x, column):
    q1 = x[column].quantile(0.25)
    q3 = x[column].quantile(0.75)
    iqr = 1.5 * (q3 - q1)
    y=x[x[column]> (q3+iqr) | (x[column] <(q1-iqr))]
    return len(y)

# %%
print("price IQR Outliers :",findOutliers(df,'price'))
print("durationIQR Outliers :",findOutliers(df,'duration'))
print("days_left IQR Outliers :", findOutliers(df,'days_left'))
# Out:
# price IQR Outliers : 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 300148    False
# 300149    False
# 300150    False
# 300151    False
# 300152    False
# Name: price, Length: 300153, dtype: bool
# durationIQR Outliers : 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 300148    False
# 300149    False
# 300150    False
# 300151    False
# 300152    False
# Name: duration, Length: 300153, dtype: bool
# days_left IQR Outliers : 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 300148    False
# 300149    False
# 300150    False
# 300151    False
# 300152    False
# Name: days_left, Length: 300153, dtype: bool

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.subplot(151)
df[['duration']].boxplot()
plt.ylabel("Time")

plt.subplot(153)
df[['days_left']].boxplot()
plt.ylabel("Days")

plt.subplot(155)
df[['price']].boxplot()
plt.ylabel("Price")
plt.show()

# %%
df_origin=df.copy()

# %%
outlier=df[(abs((df['price']-df['price'].mean())/df['price'].std()))>1.96].index

clean_df=df.drop(outlier)
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 287660 entries, 0 to 300146
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           287660 non-null  object
#  1   flight            287660 non-null  object
#  2   source_city       287660 non-null  object
#  3   departure_time    287660 non-null  object
#  4   stops             287660 non-null  object
#  5   arrival_time      287660 non-null  object
#  6   destination_city  287660 non-null  object
#  7   class             287660 non-null  object
#  8   duration          287660 non-null  float64
#  9   days_left         287660 non-null  int64
#  10  price             287660 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 26.3+ MB

# %%
plt.figure(figsize=(4,5))
clean_df[['price']].boxplot()
plt.show()

# %%
def changeOutliers(x, column):
    q1 = x[column].quantile(0.25)
    q3 = x[column].quantile(0.75)
    iqr = 1.5 * (q3 - q1)
    Min = (q1 - iqr)
    Max = q3 + iqr
    x.loc[(x[column] > Max), column] = Max
    x.loc[(x[column] < Min), column] = Min
    return x

clean_df = changeOutliers(df, 'price')
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.2+ MB

# %%
print("price IQR Outliers :",findOutliers(clean_df,'price'))
# Out:
# price IQR Outliers : 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 300148    False
# 300149    False
# 300150    False
# 300151    False
# 300152    False
# Name: price, Length: 300153, dtype: bool

# %%
plt.figure(figsize=(4,5))
clean_df[['price']].boxplot()
plt.show()

# %%
df['distance']=pd.cut(df['duration'], bins=[0,5,10,df['duration'].max()], labels=['short','medium','long'])
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price distance
# 0           Mumbai  Economy      2.17          1   5953    short
# 1           Mumbai  Economy      2.33          1   5953    short
# 2           Mumbai  Economy      2.17          1   5956    short
# 3           Mumbai  Economy      2.25          1   5955    short
# 4           Mumbai  Economy      2.33          1   5955    short

# %%
df['distance'].value_counts()
# Out:
# distance
# long      169879
# medium     84761
# short      45513
# Name: count, dtype: int64

# %%
df['pricec_rate']=pd.qcut(df['price'],4, labels=['cheap','nomal' ,'expensive', 'too expensive'])
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price distance pricec_rate
# 0           Mumbai  Economy      2.17          1   5953    short       nomal
# 1           Mumbai  Economy      2.33          1   5953    short       nomal
# 2           Mumbai  Economy      2.17          1   5956    short       nomal
# 3           Mumbai  Economy      2.25          1   5955    short       nomal
# 4           Mumbai  Economy      2.33          1   5955    short       nomal

# %%
# 예를 들어, 'price_rate' 열을 0으로 초기화하여 추가하는 경우
df['price_rate'] = 0

# %%
print(df.columns)
# Out:
# Index(['airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price', 'distance', 'pricec_rate', 'price_rate'],
#       dtype='object')

# %%
df['price_rate'].value_counts()
# Out:
# price_rate
# 0    300153
# Name: count, dtype: int64

# %%
df=df_origin.copy()
df["label_encoding"] = pd.factorize(df["airline"])[0].reshape(-1,1)
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price  label_encoding
# 0           Mumbai  Economy      2.17          1   5953               0
# 1           Mumbai  Economy      2.33          1   5953               0
# 2           Mumbai  Economy      2.17          1   5956               1
# 3           Mumbai  Economy      2.25          1   5955               2
# 4           Mumbai  Economy      2.33          1   5955               2

# %%
print(df['airline'].value_counts())
print(df['label_encoding'].value_counts())
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64
# label_encoding
# 2    127859
# 5     80892
# 4     43120
# 3     23173
# 1     16098
# 0      9011
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
df["airline_Label_Encoder"] = le.fit_transform(df['airline'])
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price  label_encoding  \
# 0           Mumbai  Economy      2.17          1   5953               0
# 1           Mumbai  Economy      2.33          1   5953               0
# 2           Mumbai  Economy      2.17          1   5956               1
# 3           Mumbai  Economy      2.25          1   5955               2
# 4           Mumbai  Economy      2.33          1   5955               2
#
#    airline_Label_Encoder
# 0                      4
# 1                      4
# 2                      0
# 3                      5
# 4                      5

# %%
print(df['airline'].value_counts())
print(df['airline_Label_Encoder'].value_counts())
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64
# airline_Label_Encoder
# 5    127859
# 1     80892
# 3     43120
# 2     23173
# 0     16098
# 4      9011
# Name: count, dtype: int64

# %%
le.inverse_transform(df["airline_Label_Encoder"]).reshape(-1,1)
# Out:
# array([['SpiceJet'],
#        ['SpiceJet'],
#        ['AirAsia'],
#        ...,
#        ['Vistara'],
#        ['Vistara'],
#        ['Vistara']], dtype=object)

# %%
df=df_origin.copy()
pd.get_dummies(df['class'])
# Out:
#         Business  Economy
# 0          False     True
# 1          False     True
# 2          False     True
# 3          False     True
# 4          False     True
# ...          ...      ...
# 300148      True    False
# 300149      True    False
# 300150      True    False
# 300151      True    False
# 300152      True    False
#
# [300153 rows x 2 columns]

# %%
df=pd.get_dummies(df, columns=['class'])
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city  duration  days_left  price  class_Business  class_Economy
# 0           Mumbai      2.17          1   5953           False           True
# 1           Mumbai      2.33          1   5953           False           True
# 2           Mumbai      2.17          1   5956           False           True
# 3           Mumbai      2.25          1   5955           False           True
# 4           Mumbai      2.33          1   5955           False           True

# %%
df=df_origin.copy()
from sklearn.preprocessing import OneHotEncoder
oh = OneHotEncoder()
encoder = oh.fit_transform(df['class'].values.reshape(-1,1)).toarray()
df_OneHot = pd.DataFrame(encoder, columns=["class_"+str(oh.categories_[0]
[i]) for i in range (len(oh.categories_[0]))])

df1 = pd.concat([df, df_OneHot], axis=1)
df1.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price  class_Business  \
# 0           Mumbai  Economy      2.17          1   5953             0.0
# 1           Mumbai  Economy      2.33          1   5953             0.0
# 2           Mumbai  Economy      2.17          1   5956             0.0
# 3           Mumbai  Economy      2.25          1   5955             0.0
# 4           Mumbai  Economy      2.33          1   5955             0.0
#
#    class_Economy
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
